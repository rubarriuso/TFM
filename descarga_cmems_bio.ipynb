# %% [markdown]
# Marine Copernicus Servie Product ID: OCEANCOLOUR_GLO_BGC_L4_MY_009_104
#
# (4x4Km)   max date:2025-11-01
#
# Mass concentration of chlorophyll a in sea water CHL [mg/m3]
#
# Primary productivity of biomass expressed as carbon PP [mg/m2/day]
#
# Mass concentration of suspended matter in sea water SPM [g/m3]
#
# Secchi depth of sea water ZSD [m]
#
# Volume absorption coefficient of radiative flux in sea water due to dissolved organic matter and non algal particles CDM [m-1]

# %%
import copernicusmarine
import xarray as xr
import numpy as np
from dask.diagnostics import ProgressBar
# import xesmf as xe
import json

# %%
dryrun=False  # Set to True to simulate download without actually downloading

# %%
with open("./data/bbox.json", "r") as f:
    bbox = json.load(f)

min_lon, min_lat, max_lon, max_lat = [
    bbox["min_lon"],
    bbox["min_lat"],
    bbox["max_lon"],
    bbox["max_lat"]
]
print(min_lon, min_lat, max_lon, max_lat)

start_date = "2012-01-01"
end_date = None #Hasta la fecha maxima de los datos copernicusmarine
# Out:
# -66.0 -57.0 -52.0 -40.0

# %%
# Mass concentration of chlorophyll a in sea water CHL [mg/m3]
copernicusmarine.subset(
    dataset_id="cmems_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M",
    variables=["CHL"],
    minimum_latitude=min_lat, minimum_longitude=min_lon,
    maximum_latitude=max_lat, maximum_longitude=max_lon,
    start_datetime=start_date, end_datetime=end_date,
    file_format="zarr",
    output_filename = "cmems_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M.zarr",
    output_directory="./resources/copernicus_marine_service",
    chunk_size_limit=50_000_000,
    overwrite=True,
    dry_run=dryrun # False to download and True to only simulate
)
# Out:
# INFO - 2026-06-01T23:30:56Z - Selected dataset version: "202603"
# INFO - 2026-06-01T23:30:56Z - Selected dataset part: "default"
# INFO - 2026-06-01T23:30:58Z - Starting download. Please wait...
# 100%|██████████| 10/10 [01:18<00:00,  7.84s/it]
# INFO - 2026-06-01T23:32:17Z - Successfully downloaded to resources\copernicus_marine_service\cmems_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M.zarr
# ResponseSubset(file_path=WindowsPath('resources/copernicus_marine_service/cmems_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M.zarr'), output_directory=WindowsPath('resources/copernicus_marine_service'), filename='cmems_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M.zarr', file_size=90.00970229007635, data_transfer_size=133.94858015267175, variables=['CHL'], coordinates_extent=[GeographicalExtent(minimum=-65.97916412353516, maximum=-52.02082824707031, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=-56.97917175292969, maximum=-40.020835876464844, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='2012-01-01T00:00:00+00:00', maximum='2026-04-01T00:00:00+00:00', unit='iso8601', coordinate_id='time')], status=<StatusCode.SUCCESS: '000'>, message=<StatusMessage.SUCCESS: 'The request was successful.'>, file_status=<FileStatus.OVERWRITTEN: 'OVERWRITTEN'>)

# %%
#Primary productivity of biomass expressed as carbon PP [mg/m2/day]
copernicusmarine.subset(
    dataset_id="cmems_obs-oc_glo_bgc-pp_my_l4-multi-4km_P1M",
    variables=["PP"],
    minimum_latitude=min_lat, minimum_longitude=min_lon,
    maximum_latitude=max_lat, maximum_longitude=max_lon,
    start_datetime=start_date, end_datetime=end_date,
    file_format="zarr",
    output_filename = "cmems_obs-oc_glo_bgc-pp_my_l4-multi-4km_P1M.zarr",
    output_directory="./resources/copernicus_marine_service",
    chunk_size_limit=50_000_000,
    overwrite=True,
    dry_run=dryrun # False to download and True to only simulate
)
# Out:
# INFO - 2026-06-01T23:32:18Z - Selected dataset version: "202603"
# INFO - 2026-06-01T23:32:18Z - Selected dataset part: "default"
# INFO - 2026-06-01T23:32:20Z - Starting download. Please wait...
# 100%|██████████| 10/10 [01:11<00:00,  7.13s/it]
# INFO - 2026-06-01T23:33:31Z - Successfully downloaded to resources\copernicus_marine_service\cmems_obs-oc_glo_bgc-pp_my_l4-multi-4km_P1M.zarr
# ResponseSubset(file_path=WindowsPath('resources/copernicus_marine_service/cmems_obs-oc_glo_bgc-pp_my_l4-multi-4km_P1M.zarr'), output_directory=WindowsPath('resources/copernicus_marine_service'), filename='cmems_obs-oc_glo_bgc-pp_my_l4-multi-4km_P1M.zarr', file_size=90.00970229007635, data_transfer_size=133.94858015267175, variables=['PP'], coordinates_extent=[GeographicalExtent(minimum=-65.97916412353516, maximum=-52.02082824707031, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=-56.97917175292969, maximum=-40.020835876464844, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='2012-01-01T00:00:00+00:00', maximum='2026-04-01T00:00:00+00:00', unit='iso8601', coordinate_id='time')], status=<StatusCode.SUCCESS: '000'>, message=<StatusMessage.SUCCESS: 'The request was successful.'>, file_status=<FileStatus.OVERWRITTEN: 'OVERWRITTEN'>)

# %%
# Mass concentration of suspended matter in sea water SPM [g/m3]
# Secchi depth of sea water ZSD [m]
copernicusmarine.subset(
    dataset_id="cmems_obs-oc_glo_bgc-transp_my_l4-multi-4km_P1M",
    variables=["SPM", "ZSD"],
    minimum_latitude=min_lat, minimum_longitude=min_lon,
    maximum_latitude=max_lat, maximum_longitude=max_lon,
    start_datetime=start_date, end_datetime=end_date,
    file_format="zarr",
    output_filename = "cmems_obs-oc_glo_bgc-transp_my_l4-multi-4km_P1M.zarr",
    output_directory="./resources/copernicus_marine_service",
    chunk_size_limit=50_000_000,
    overwrite=True,
    dry_run=dryrun # False to download and True to only simulate
)
# Out:
# INFO - 2026-06-01T23:33:33Z - Selected dataset version: "202603"
# INFO - 2026-06-01T23:33:33Z - Selected dataset part: "default"
# INFO - 2026-06-01T23:33:35Z - Starting download. Please wait...
# 100%|██████████| 20/20 [01:58<00:00,  5.92s/it]
# INFO - 2026-06-01T23:35:33Z - Successfully downloaded to resources\copernicus_marine_service\cmems_obs-oc_glo_bgc-transp_my_l4-multi-4km_P1M.zarr
# ResponseSubset(file_path=WindowsPath('resources/copernicus_marine_service/cmems_obs-oc_glo_bgc-transp_my_l4-multi-4km_P1M.zarr'), output_directory=WindowsPath('resources/copernicus_marine_service'), filename='cmems_obs-oc_glo_bgc-transp_my_l4-multi-4km_P1M.zarr', file_size=180.0064045801527, data_transfer_size=267.8971603053435, variables=['SPM', 'ZSD'], coordinates_extent=[GeographicalExtent(minimum=-65.97916412353516, maximum=-52.02082824707031, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=-56.97917175292969, maximum=-40.020835876464844, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='2012-01-01T00:00:00+00:00', maximum='2026-04-01T00:00:00+00:00', unit='iso8601', coordinate_id='time')], status=<StatusCode.SUCCESS: '000'>, message=<StatusMessage.SUCCESS: 'The request was successful.'>, file_status=<FileStatus.OVERWRITTEN: 'OVERWRITTEN'>)

# %%
# Volume absorption coefficient of radiative flux in sea water due to dissolved organic matter and non algal particles CDM [m-1]
copernicusmarine.subset(
    dataset_id="cmems_obs-oc_glo_bgc-optics_my_l4-multi-4km_P1M",
    variables=["CDM"],
    minimum_latitude=min_lat, minimum_longitude=min_lon,
    maximum_latitude=max_lat, maximum_longitude=max_lon,
    start_datetime=start_date, end_datetime=end_date,
    file_format="zarr",
    output_filename = "cmems_obs-oc_glo_bgc-optics_my_l4-multi-4km_P1M.zarr",
    output_directory="./resources/copernicus_marine_service",
    chunk_size_limit=50_000_000,
    overwrite=True,
    dry_run=dryrun # False to download and True to only simulate
)
# Out:
# INFO - 2026-06-01T23:35:35Z - Selected dataset version: "202603"
# INFO - 2026-06-01T23:35:35Z - Selected dataset part: "default"
# INFO - 2026-06-01T23:35:38Z - Starting download. Please wait...
# 100%|██████████| 10/10 [01:16<00:00,  7.63s/it]
# INFO - 2026-06-01T23:36:55Z - Successfully downloaded to resources\copernicus_marine_service\cmems_obs-oc_glo_bgc-optics_my_l4-multi-4km_P1M.zarr
# ResponseSubset(file_path=WindowsPath('resources/copernicus_marine_service/cmems_obs-oc_glo_bgc-optics_my_l4-multi-4km_P1M.zarr'), output_directory=WindowsPath('resources/copernicus_marine_service'), filename='cmems_obs-oc_glo_bgc-optics_my_l4-multi-4km_P1M.zarr', file_size=90.00970229007635, data_transfer_size=133.94858015267175, variables=['CDM'], coordinates_extent=[GeographicalExtent(minimum=-65.97916412353516, maximum=-52.02082824707031, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=-56.97917175292969, maximum=-40.020835876464844, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='2012-01-01T00:00:00+00:00', maximum='2026-04-01T00:00:00+00:00', unit='iso8601', coordinate_id='time')], status=<StatusCode.SUCCESS: '000'>, message=<StatusMessage.SUCCESS: 'The request was successful.'>, file_status=<FileStatus.OVERWRITTEN: 'OVERWRITTEN'>)
