# %% [markdown]
# #### Crear un json con las cordenadas del area de estudio en base a la pesquería.
# Estas cordenadas serán utilizadas en todo el procesado, en base a la huella de la pesquería de los datos del IEO
